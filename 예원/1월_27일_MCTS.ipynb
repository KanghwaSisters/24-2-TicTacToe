# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from math import sqrt

# %% [markdown]
# # 00 Game Info

# %%
STATE_SIZE = (3,3)
N_ACTIONS = STATE_SIZE[0]*STATE_SIZE[1]
STATE_DIM = 3 # first player 정보 넣음
BOARD_SHAPE = (STATE_DIM, 3, 3)

# %% [markdown]
# # 01 HYPER PARAMS

# %%
C_PUCT = 2.5
N_SIMULATIONS = 100

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # 02 Env+State

# %%
import os

# 파일 복사 명령어 실행
os.system('cp "/content/drive/My Drive/Colab Notebooks/공통 environment+state.ipynb" "/content/"')
# Out:
# 0

# %%
import nbformat

notebook_path = "/content/공통 environment+state.ipynb"
with open(notebook_path, "r", encoding="utf-8") as f:
    notebook_content = nbformat.read(f, as_version=4)

# 각 코드 셀 출력 및 실행
for cell in notebook_content.cells:
    if cell.cell_type == "code":
        print(f"실행 중인 코드:\n{cell.source}\n{'='*40}")
        exec(cell.source)
# Out:
# 실행 중인 코드:
# import torch
# import torch.nn as nn
# import numpy as np
# ========================================
# 실행 중인 코드:
# STATE_SIZE = (3,3)
# N_ACTIONS = STATE_SIZE[0]*STATE_SIZE[1]
# STATE_DIM = 3 # first player 정보 넣음
# BOARD_SHAPE = (STATE_DIM, 3, 3)
# ========================================
# 실행 중인 코드:
# DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ========================================
# 실행 중인 코드:
# class Environment: #틱택토 게임 환경 정의 클래스 / 게임 규칙을 코드로 구현한 것
#     def __init__(self):
#         self.n = STATE_SIZE[0] #보드 행 또는 열 크기
#         self.num_actions = self.n ** 2
#         self.action_space = np.arange(self.num_actions)
#         self.reward_dict = {'win': 1, 'lose': -1, 'draw': 0} #결과에 따른 보상 정의
#         #승리 1점 / 패배 -1점 / 무승부 0점
#
#
#     def step(self, present_state, action_idx): #현재 상태에서 주어진 행동에 따라 게임 진행 / 행동 결과를 계산
#         """
#         present_state에 대해 action_idx의 행동에 따라 게임을 한 턴 진행시키고
#         next_state, is_done, is_lose를 반환한다.
#         """
#         #action_idx: 플레이어가 선택한 행동의 인덱스 / 보드 칸
#         #현재 상태에서 행동하는 행동을 수행하여 다음 상태를 계산
#         next_state = present_state.next(action_idx)
#         is_done, is_lose = next_state.check_done()
#         #next_state에서 게임이 종료되었는지 확인
#         #현재 플레이어가 패배했는지 확인
#
#         return next_state, is_done, is_lose
#
#
#     def get_reward(self, final_state): #게임 종료 후 보상 계산 / 승패 및 무승부 판정
#         """
#         게임이 종료된 state에 대해 각 플레이어의 reward를 반환한다.
#         final_state: 게임이 종료된 state
#         note: final_state가 is_lose라면, 해당 state에서 행동할 차례였던 플레이어가 패배한 것.
#         """
#         '''
#         장예원 수정!
#         '''
#         is_done, is_lose = final_state.check_done()  # 게임 종료 및 패배 여부 확인
#
#         # 승리, 패배, 무승부 정확하게 판별
#         if not is_done:
#             return 0  # 게임이 아직 끝나지 않았으면 보상을 주지 않음
#
#         if is_lose:
#             return self.reward_dict['lose']  # 패배 시 -1
#
#         if final_state.total_pieces_count() == self.num_actions:
#             return self.reward_dict['draw']  # 무승부 시 0
#
#         return self.reward_dict['win']  # 승리 시 +1
#
#
#     def render(self, state): #게임 상태 출력
#         '''
#         입력받은 state를 문자열로 출력한다.
#         X: first_player, O: second_player
#         '''
#         is_first_player = state.check_first_player() #현재 차례가 첫번째 플레이어인지 확인
#         board = state.state - state.enemy_state if is_first_player else state.enemy_state - state.state
#         board = board.reshape(3,3) #현재 보드 상태를 정리
#
#         board_list = [['X' if cell == 1 else 'O' if cell == -1 else '.' for cell in row] for row in board]
#         #돌 상태를 문자로 변환 -> 읽기 쉽게 표시
#         #X: 첫번째 플레이어의 돌 / O: 두번째 플레이어의 돌 / .: 빈칸
#         formatted_board = "\n".join([" ".join(row) for row in board_list])
#         #보기 좋게 줄바꿈하여 출력
#         return formatted_board  #print() 대신 문자열 반환
# ========================================
# 실행 중인 코드:
# import copy
# ========================================
# 실행 중인 코드:
# class State(Environment):
#     def __init__(self, state=None, enemy_state=None):
#         super().__init__()
#         self.state = state if state is not None else [0] * (self.n ** 2)
#         self.enemy_state = enemy_state if enemy_state is not None else [0] * (self.n ** 2)
#
#         self.state = np.array(self.state).reshape(STATE_SIZE)
#         self.enemy_state = np.array(self.enemy_state).reshape(STATE_SIZE)
#         self.move_count = 0 # 초기 상태에서 Player 1이 선공
#
#
#     def total_pieces_count(self):
#         '''
#         이 state의 전체 돌의 개수를 반환한다.
#         '''
#         total_state = self.state + self.enemy_state
#         return np.sum(total_state)
#
#
#     def get_legal_actions(self):
#         '''
#         이 state에서 가능한 action을
#         one-hot encoding 형식의 array로 반환한다.
#         '''
#         total_state = (self.state + self.enemy_state).reshape(-1)
#         legal_actions = np.array([total_state[x] == 0 for x in self.action_space], dtype = int)
#         return legal_actions
#
#
#     def check_done(self):
#         '''
#         이 state의 done, lose 여부를 반환한다.
#         note: 상대가 행동한 후, 자신의 행동을 하기 전 이 state를 확인한다.
#         따라서 이전 state에서 상대의 행동으로 상대가 이긴 경우는 이 state의 플레이어가 진 경우이다.
#         '''
#         is_done, is_lose = False, False
#
#         # Check draw
#         if self.total_pieces_count() == self.n ** 2:
#             is_done, is_lose = True, False
#
#         # Check lose
#         lose_condition = np.concatenate([self.enemy_state.sum(axis=0), self.enemy_state.sum(axis=1), [self.enemy_state.trace], [np.fliplr(self.enemy_state).trace()]])
#         if self.n in lose_condition:
#             is_done, is_lose = True, True
#
#         return is_done, is_lose
#
#
#     def next(self, action_idx):
#         '''
#         주어진 action에 따라 다음 state를 생성한다.
#         note: 다음 state는 상대의 차례이므로 state 순서를 바꾼다.
#         '''
#         x, y =np.divmod(action_idx, self.n)
#         state = self.state.copy()
#         state[x, y] = 1
#
#         state = list(state.reshape(-1))
#         enemy_state = list(copy.copy(self.enemy_state).reshape(-1))
#
#         next_state = State(enemy_state, state)  # state와 enemy_state를 바꿔서 전달
#         next_state.move_count = self.move_count + 1  # move_count 증가
#         return next_state
#
#
#     def check_first_player(self):
#         # State()를 기본적으로 생성하면 move_count = 0이므로 check_first_player()는 항상 True
#         return self.move_count % 2 == 0
#
#
#     def get_random_action(self):
#         '''
#         이 state에서 가능한 action 중 랜덤으로 action을 반환한다.
#         '''
#         legal_actions = self.get_legal_actions()
#         legal_action_idxs = np.where(legal_actions != 0)[0]
#         action = np.random.choice(legal_action_idxs)
#         return action
#
#
#     def __str__(self):
#         return Environment().render(self)  # state를 인자로 명확히 전달
# ========================================

# %% [markdown]
# # 03 MCTS

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import math

# %% [markdown]
# ### 사전 준비 (PolicyValueNet 초기화 및 학습)

# %%
# 새로운 모델 설계
class PolicyValueNet(nn.Module):
    def __init__(self):
        super(PolicyValueNet, self).__init__()
        self.fc1 = nn.Linear(9, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 9)  # 정책 예측
        self.value_head = nn.Linear(64, 1)  # 가치 예측

        for layer in [self.fc1, self.fc2, self.fc3, self.value_head]:
            nn.init.kaiming_normal_(layer.weight, nonlinearity="leaky_relu")
            if layer.bias is not None:
                nn.init.constant_(layer.bias, 0.01)

    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), negative_slope=0.01)
        x = F.leaky_relu(self.fc2(x), negative_slope=0.01)
        policy_logits = self.fc3(x)
        value = torch.tanh(self.value_head(x))  # [-1, 1] 범위 보정
        return policy_logits, value


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
policy_model = PolicyValueNet().to(device)

# 가치 학습을 위한 간단한 학습 과정
optimizer = torch.optim.Adam(policy_model.parameters(), lr=0.005)
criterion = nn.MSELoss()

print("[DEBUG] Starting PolicyValueNet pre-training...")

for epoch in range(100):
    optimizer.zero_grad()

    board_tensor = torch.rand(1, 9).to(device)
    _, value = policy_model(board_tensor)

    target_value = torch.tensor([[0.5]], device=device)  # 학습 목표 값
    loss = criterion(value, target_value)
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"[DEBUG] Epoch {epoch}, Loss: {loss.item():.4f}")

print("[DEBUG] PolicyValueNet pre-training completed!")
# Out:
# [DEBUG] Starting PolicyValueNet pre-training...
# [DEBUG] Epoch 0, Loss: 0.3007
# [DEBUG] Epoch 10, Loss: 0.0032
# [DEBUG] Epoch 20, Loss: 0.0914
# [DEBUG] Epoch 30, Loss: 0.1587
# [DEBUG] Epoch 40, Loss: 0.0195
# [DEBUG] Epoch 50, Loss: 0.0277
# [DEBUG] Epoch 60, Loss: 0.0345
# [DEBUG] Epoch 70, Loss: 0.0516
# [DEBUG] Epoch 80, Loss: 0.0054
# [DEBUG] Epoch 90, Loss: 0.0144
# [DEBUG] PolicyValueNet pre-training completed!

# %% [markdown]
# ###  Node_m 클래스 (MCTS 노드)
# 각 MCTS 노드가 게임 상태와 정책 확률, 방문 횟수, 가치 총합을 저장하도록 설계

# %%
class Node_m: #MCTS에서 사용되는 노드 클래스
    def __init__(self, state, parent=None, prior_prob=1.0):
        self.state = state
        self.parent = parent
        self.prior_prob = prior_prob # 정책 신경망에서 예측된 행동 확률
        self.visit_count = 0 # 노드 방문 횟수
        self.total_value = 0.0 # 노드의 총 평가 가치
        self.children = {} # 행동(action) -> Node_m 매핑


    def expand(self, policy_probs): # 자식 노드 확장
        print(f"[DEBUG] expand() called with policy_probs type: {type(policy_probs)}")
        # policy_probs를 기반으로 valid_actions을 가져와서, 새로운 자식 노드를 생성
        # policy_probs가 ndarray인 경우 처리
        if isinstance(policy_probs, np.ndarray): # policy_probs가 ndarray인지 확인
            valid_actions = self.state.get_legal_actions()  # 유효한 행동 가져오기
            print(f"[DEBUG] Valid actions: {valid_actions}")
            print(f"[DEBUG] Policy probs: {policy_probs}")

            for action, prob in enumerate(policy_probs): # 인덱스와 확률로 순회
                # 유효하고 아직 확장되지 않은 경우
                if action in valid_actions and action not in self.children:
                    if prob > 0:  # 🔥 정책 확률이 0보다 큰 경우에만 확장
                        print(f"[DEBUG] Expanding action {action} with prob {prob:.4f}")
                        next_state = self.state.next(action) # 다음 상태 생성
                        # 자식 노드 추가
                        self.children[action] = Node_m(next_state, parent=self, prior_prob=prob)
                    else:
                        print(f"[WARNING] Skipping action {action} due to low policy prob: {prob:.6f}")

        else:
            for action, prob in policy_probs.items(): # 기존 로직 유지
                if action not in self.children: # 아직 확장되지 않은 경우
                    if prob > 0:
                        print(f"[DEBUG] Expanding action {action} with prob {prob:.4f}")
                        next_state = self.state.next(action) # 다음 상태 생성
                        # 자식 노드 추가
                        self.children[action] = Node_m(next_state, parent=self, prior_prob=prob)
                    else:
                        print(f"[WARNING] Skipping action {action} due to low policy prob: {prob:.6f}")


    def is_leaf(self): #자식 노드가 없는 경우 확인
        return len(self.children) == 0


    def get_ucb_score(self, total_visits): #UCB 점수를 계산하여 탐험과 활용의 균형을 맞춤
        if self.visit_count == 0:
            return float('inf')
        q_value = self.total_value / self.visit_count
        exploration_term = C_PUCT * self.prior_prob * (math.sqrt(total_visits) / (1 + self.visit_count))
        return q_value + exploration_term #q값과 탐색 가중치(C_PUCT)를 이용한 계산

# %% [markdown]
# ### MCTS 실행

# %%
class MCTSAgent: #몬테카를로 트리 탐색 알고리즘 클래스
    def __init__(self, policy_model):
        self.policy_model = policy_model


    def run_simulation(self, root): #MCTS 시뮬레이션 실행
        node = root
        search_path = [node]

        # Selection
        while not node.is_leaf(): # 1. Selection: 트리를 따라 확장되지 않은 노드로 이동
            total_visits = sum(child.visit_count for child in node.children.values())
            # 자식 노드 중 UCB 점수가 최대인 노드 선택
            node = max(node.children.values(), key=lambda child: child.get_ucb_score(total_visits))
            search_path.append(node)

        # Expansion & Evaluation: 리프 노드 확장
        if not node.state.check_done()[0]:  #check_done: 게임 종료 여부 & 패배 여부 반환
            policy, value = self._evaluate_policy(node.state)
            print(f"[DEBUG] Evaluated value: {value:.2f}")  # 디버깅 추가
            node.expand(policy)
        else:
            value = self._evaluate_terminal(node.state)

        # Backpropagation: 부모 노드로 값을 전달
        self._backpropagate(search_path, value)


    def _evaluate_policy(self, state):
        board_tensor = torch.tensor(state.state - state.enemy_state, dtype=torch.float32).view(1, -1).to(device)

        with torch.no_grad(): #정책 및 상태 평가 (정책 신경망 활용)
            policy_logits, value = self.policy_model(board_tensor)

        policy_probs = torch.softmax(policy_logits, dim=-1).squeeze(0).cpu().numpy() #정책을 확률로 변환
        legal_actions = np.where(state.get_legal_actions() != 0)[0]
        action_probs = {action: policy_probs[action] for action in legal_actions}

        print(f"Policy probs from model: {policy_probs}")
        print(f"Action probs after filtering: {action_probs}")

        return action_probs, value.item()


    def _evaluate_terminal(self, state): #터미널 상태에서 가치 평가
        return state.get_reward(state)


    def _backpropagate(self, search_path, value): #시뮬레이션 결과를 역전파
        for node in reversed(search_path):
            node.visit_count += 1
            node.total_value += value  # 가치 업데이트가 확실히 반영됨
            print(f"[DEBUG] Backpropagation - Node visit_count: {node.visit_count}, total_value: {node.total_value:.2f}")

            value = -value  # 상대방 관점에서 반전


    def get_action_probs(self, root, temp=1.5): #행동 확률 계산 / 온도 적용하여 탐색과 활용 조정
        if not isinstance(root, Node_m):  # root가 Node인지 확인
            root = Node_m(root)  # 자동 변환 추가

        if not root.children:  # 자식 노드가 없을 경우
            num_actions = len(root.state.get_legal_actions())  # 가능한 행동 개수
            return np.ones(num_actions) / num_actions  # 균등 확률 반환

        visits = np.array([child.visit_count for child in root.children.values()])

        if visits.sum() == 0:  # 방문 횟수가 0인 경우 처리
            return np.ones_like(visits) / len(visits)

        if temp == 0:  # 가장 많이 방문한 행동 선택 (탐색 X)
            best_action = np.argmax(visits)
            probs = np.zeros_like(visits)
            probs[best_action] = 1
            return probs

        # 온도(temp) 조정: 낮을수록 가장 방문 많은 행동을 선택하는 경향
        visits = visits ** (1 / temp)
        return visits / visits.sum()


    def get_action(self, root, temp=1.0): #행동 확률에 따라 최종 행동 선택
        probs = self.get_action_probs(root, temp)
        if probs is None or len(probs) == 0:
            return np.random.choice(len(probs))  # 가능한 행동 중 랜덤 선택
        return np.random.choice(len(probs), p=probs)  # 행동 확률 기반 선택

# %% [markdown]
# ## Test Code

# %%
state = State()
# 실행
mcts = MCTSAgent(policy_model)
root = Node_m(state)  # 초기 상태

for i in range(N_SIMULATIONS):
    print(f"\n[SIMULATION {i + 1}]")
    mcts.run_simulation(root)

    # 탐색 후 `get_action()`을 사용하여 행동 선택
    action = mcts.get_action(root, temp=1.0)
    print(f"[RESULT] Chosen action: {action}")

print("MCTS 실행 완료!")
# Out:
# [SIMULATION 1]
# Policy probs from model: [0.11570105 0.10756159 0.11113896 0.11870289 0.11163919 0.10005549
#  0.11230598 0.1156844  0.10721047]
# Action probs after filtering: {0: 0.11570105, 1: 0.10756159, 2: 0.11113896, 3: 0.11870289, 4: 0.111639194, 5: 0.100055486, 6: 0.112305984, 7: 0.1156844, 8: 0.10721047}
# [DEBUG] Evaluated value: 0.15
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1157
# [DEBUG] Expanding action 1 with prob 0.1076
# [DEBUG] Expanding action 2 with prob 0.1111
# [DEBUG] Expanding action 3 with prob 0.1187
# [DEBUG] Expanding action 4 with prob 0.1116
# [DEBUG] Expanding action 5 with prob 0.1001
# [DEBUG] Expanding action 6 with prob 0.1123
# [DEBUG] Expanding action 7 with prob 0.1157
# [DEBUG] Expanding action 8 with prob 0.1072
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.15
# [RESULT] Chosen action: 3
#
# [SIMULATION 2]
# Policy probs from model: [0.10779165 0.05656747 0.0522506  0.15354063 0.10817146 0.12777923
#  0.24954557 0.06541225 0.07894118]
# Action probs after filtering: {1: 0.05656747, 2: 0.0522506, 3: 0.15354063, 4: 0.10817146, 5: 0.12777923, 6: 0.24954557, 7: 0.06541225, 8: 0.07894118}
# [DEBUG] Evaluated value: -0.37
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 1 with prob 0.
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.18
# [DEBUG] Backpropagation - Node visit_count: 8, total_value: -0.10
# [DEBUG] Backpropagation - Node visit_count: 48, total_value: 6.25
# [RESULT] Chosen action: 7
#
# [SIMULATION 49]
# Policy probs from model: [0.11097051 0.10277689 0.06969564 0.12000494 0.13680431 0.06026986
#  0.15494972 0.15571436 0.08881371]
# Action probs after filtering: {0: 0.11097051, 1: 0.10277689, 3: 0.120004945, 4: 0.13680431, 5: 0.060269862, 6: 0.15494972, 8: 0.08881371}
# [DEBUG] Evaluated value: -0.07
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1110
# [DEBUG] Expanding action 1 with prob 0.1028
# [DEBUG] Expanding action 3 with prob 0.1200
# [DEBUG] Expanding action 4 with prob 0.1368
# [DEBUG] Expanding action 5 with prob 0.0603
# [DEBUG] Expanding action 6 with prob 0.1549
# [DEBUG] Expanding action 8 with prob 0.0888
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.07
# [DEBUG] Backpropagation - Node visit_count: 8, total_value: -0.10
# [DEBUG] Backpropagation - Node visit_count: 49, total_value: 6.18
# [RESULT] Chosen action: 6
#
# [SIMULATION 50]
# Policy probs from model: [0.1969135  0.06715811 0.08864915 0.1689176  0.12980174 0.08234141
#  0.08546855 0.04964772 0.13110225]
# Action probs after filtering: {0: 0.1969135, 2: 0.08864915, 3: 0.1689176, 4: 0.12980174, 5: 0.08234141, 7: 0.049647722, 8: 0.13110225}
# [DEBUG] Evaluated value: -0.20
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1969
# [DEBUG] Expanding action 2 with prob 0.0886
# [DEBUG] Expanding action 3 with prob 0.1689
# [DEBUG] Expanding action 4 with prob 0.1298
# [DEBUG] Expanding action 5 with prob 0.0823
# [DEBUG] Expanding action 7 with prob 0.0496
# [DEBUG] Expanding action 8 with prob 0.1311
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.20
# [DEBUG] Backpropagation - Node visit_count: 7, total_value: -0.15
# [DEBUG] Backpropagation - Node visit_count: 50, total_value: 5.98
# [RESULT] Chosen action: 5
#
# [SIMULATION 51]
# Policy probs from model: [0.22054094 0.07810414 0.05566277 0.14904371 0.10661932 0.07409268
#  0.11520716 0.08355662 0.11717265]
# Action probs after filtering: {0: 0.22054094, 2: 0.055662766, 3: 0.14904371, 4: 0.10661932, 5: 0.07409268, 6: 0.11520716, 8: 0.11717265}
# [DEBUG] Evaluated value: 0.06
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.2205
# [DEBUG] Expanding action 2 with prob 0.0557
# [DEBUG] Expanding action 3 with prob 0.1490
# [DEBUG] Expanding action 4 with prob 0.1066
# [DEBUG] Expanding action 5 with prob 0.0741
# [DEBUG] Expanding action 6 with prob 0.1152
# [DEBUG] Expanding action 8 with prob 0.1172
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.06
# [DEBUG] Backpropagation - Node visit_count: 8, total_value: -0.21
# [DEBUG] Backpropagation - Node visit_count: 51, total_value: 6.03
# [RESULT] Chosen action: 8
#
# [SIMULATION 52]
# Policy probs from model: [0.12529667 0.03396535 0.04483039 0.25740778 0.05575896 0.06982739
#  0.1601564  0.06860327 0.1841538 ]
# Action probs after filtering: {0: 0.12529667, 1: 0.033965353, 2: 0.04483039, 4: 0.055758957, 5: 0.06982739, 7: 0.06860327, 8: 0.1841538}
# [DEBUG] Evaluated value: -0.14
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1253
# [DEBUG] Expanding action 1 with prob 0.0340
# [DEBUG] Expanding action 2 with prob 0.0448
# [DEBUG] Expanding action 4 with prob 0.0558
# [DEBUG] Expanding action 5 with prob 0.0698
# [DEBUG] Expanding action 7 with prob 0.0686
# [DEBUG] Expanding action 8 with prob 0.1842
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.14
# [DEBUG] Backpropagation - Node visit_count: 5, total_value: -0.61
# [DEBUG] Backpropagation - Node visit_count: 52, total_value: 5.90
# [RESULT] Chosen action: 1
#
# [SIMULATION 53]
# Policy probs from model: [0.11691424 0.03832602 0.02485598 0.3178281  0.0564567  0.12232049
#  0.10696507 0.05908392 0.15724953]
# Action probs after filtering: {0: 0.11691424, 1: 0.038326018, 2: 0.024855979, 3: 0.3178281, 5: 0.12232049, 7: 0.05908392, 8: 0.15724953}
# [DEBUG] Evaluated value: 0.21
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1169
# [DEBUG] Expanding action 1 with prob 0.0383
# [DEBUG] Expanding action 2 with prob 0.0249
# [DEBUG] Expanding action 3 with prob 0.3178
# [DEBUG] Expanding action 5 with prob 0.1223
# [DEBUG] Expanding action 7 with prob 0.0591
# [DEBUG] Expanding action 8 with prob 0.1572
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.21
# [DEBUG] Backpropagation - Node visit_count: 6, total_value: -0.82
# [DEBUG] Backpropagation - Node visit_count: 53, total_value: 6.11
# [RESULT] Chosen action: 8
#
# [SIMULATION 54]
# Policy probs from model: [0.08531369 0.12409886 0.08604424 0.08161595 0.12519944 0.07277641
# ...
# [DEBUG] Expanding action 4 with prob 0.0338
# [DEBUG] Expanding action 5 with prob 0.0399
# [DEBUG] Expanding action 6 with prob 0.0846
# [DEBUG] Expanding action 7 with prob 0.2021
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.44
# [DEBUG] Backpropagation - Node visit_count: 2, total_value: -0.35
# [DEBUG] Backpropagation - Node visit_count: 12, total_value: 0.98
# [DEBUG] Backpropagation - Node visit_count: 83, total_value: 3.58
# [RESULT] Chosen action: 4
#
# [SIMULATION 84]
# Policy probs from model: [0.06418716 0.06156153 0.03478144 0.09718159 0.08831003 0.06667984
#  0.36427507 0.14261669 0.08040665]
# Action probs after filtering: {3: 0.09718159, 4: 0.088310026, 5: 0.066679835, 6: 0.36427507, 7: 0.14261669, 8: 0.08040665}
# [DEBUG] Evaluated value: 0.02
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 3 with prob 0.0972
# [DEBUG] Expanding action 4 with prob 0.0883
# [DEBUG] Expanding action 5 with prob 0.0667
# [DEBUG] Expanding action 6 with prob 0.3643
# [DEBUG] Expanding action 7 with prob 0.1426
# [DEBUG] Expanding action 8 with prob 0.0804
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.02
# [DEBUG] Backpropagation - Node visit_count: 2, total_value: 0.30
# [DEBUG] Backpropagation - Node visit_count: 13, total_value: 1.00
# [DEBUG] Backpropagation - Node visit_count: 84, total_value: 3.56
# [RESULT] Chosen action: 6
#
# [SIMULATION 85]
# Policy probs from model: [0.06088356 0.06795923 0.06898688 0.36433583 0.03223705 0.07326835
#  0.08241145 0.09759222 0.15232545]
# Action probs after filtering: {0: 0.060883563, 3: 0.36433583, 4: 0.03223705, 5: 0.07326835, 6: 0.082411446, 8: 0.15232545}
# [DEBUG] Evaluated value: 0.43
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0609
# [DEBUG] Expanding action 3 with prob 0.3643
# [DEBUG] Expanding action 4 with prob 0.0322
# [DEBUG] Expanding action 5 with prob 0.0733
# [DEBUG] Expanding action 6 with prob 0.0824
# [DEBUG] Expanding action 8 with prob 0.1523
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.43
# [DEBUG] Backpropagation - Node visit_count: 3, total_value: -0.59
# [DEBUG] Backpropagation - Node visit_count: 14, total_value: 1.43
# [DEBUG] Backpropagation - Node visit_count: 85, total_value: 3.13
# [RESULT] Chosen action: 1
#
# [SIMULATION 86]
# Policy probs from model: [0.02783967 0.04463068 0.04752842 0.18723722 0.04716995 0.10815702
#  0.2258397  0.19782668 0.11377066]
# Action probs after filtering: {2: 0.047528423, 3: 0.18723722, 4: 0.047169946, 6: 0.2258397, 7: 0.19782668, 8: 0.113770664}
# [DEBUG] Evaluated value: 0.09
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 2 with prob 0.0475
# [DEBUG] Expanding action 3 with prob 0.1872
# [DEBUG] Expanding action 4 with prob 0.0472
# [DEBUG] Expanding action 6 with prob 0.2258
# [DEBUG] Expanding action 7 with prob 0.1978
# [DEBUG] Expanding action 8 with prob 0.1138
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.09
# [DEBUG] Backpropagation - Node visit_count: 2, total_value: -0.04
# [DEBUG] Backpropagation - Node visit_count: 15, total_value: 1.52
# [DEBUG] Backpropagation - Node visit_count: 86, total_value: 3.04
# [RESULT] Chosen action: 8
#
# [SIMULATION 87]
# Policy probs from model: [0.03972027 0.00839792 0.02455577 0.27454904 0.02207402 0.08917743
#  0.07220358 0.22948803 0.23983397]
# Action probs after filtering: {2: 0.024555773, 3: 0.27454904, 4: 0.022074018, 5: 0.08917743, 7: 0.22948803, 8: 0.23983397}
# [DEBUG] Evaluated value: -0.01
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 2 with prob 0.0246
# [DEBUG] Expanding action 3 with prob 0.2745
# [DEBUG] Expanding action 4 with prob 0.0221
# [DEBUG] Expanding action 5 with prob 0.0892
# [DEBUG] Expanding action 7 with prob 0.2295
# [DEBUG] Expanding action 8 with prob 0.2398
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.01
# [DEBUG] Backpropagation - Node visit_count: 2, total_value: -0.19
# [DEBUG] Backpropagation - Node visit_count: 16, total_value: 1.51
# [DEBUG] Backpropagation - Node visit_count: 87, total_value: 3.05
# [RESULT] Chosen action: 1
#
# [SIMULATION 88]
# Policy probs from model: [0.08305393 0.02842883 0.08253807 0.23021567 0.03696501 0.03570323
#  0.20673633 0.229334   0.06702487]
# Action probs after filtering: {2: 0.08253807, 3: 0.23021567, 5: 0.035703227, 6: 0.20673633, 7: 0.229334, 8: 0.06702487}
# [DEBUG] Evaluated value: 0.46
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 2 with prob 0.0825
# [DEBUG] Expanding action 3 with prob 0.2302
# [DEBUG] Expanding action 5 with prob 0.0357
# [DEBUG] Expanding action 6 with prob 0.2067
# [DEBUG] Expanding action 7 with prob 0.2293
# [DEBUG] Expanding action 8 with prob 0.0670
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.46
# [DEBUG] Backpropagation - Node visit_count: 2, total_value: -0.23
# [DEBUG] Backpropagation - Node visit_count: 17, total_value: 1.97
# [DEBUG] Backpropagation - Node visit_count: 88, total_value: 2.59
# [RESULT] Chosen action: 6
#
# [SIMULATION 89]
# Policy probs from model: [0.17143068 0.06634215 0.09568261 0.11377928 0.08401047 0.0425507
#  0.2646193  0.0935683  0.06801657]
# Action probs after filtering: {0: 0.17143068, 4: 0.08401047, 5: 0.0425507, 6: 0.2646193, 7: 0.0935683, 8: 0.068016574}
# [DEBUG] Evaluated value: -0.17
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1714
# [DEBUG] Expanding action 4 with prob 0.0840
# [DEBUG] Expanding action 5 with prob 0.0426
# [DEBUG] Expanding action 6 with prob 0.2646
# [DEBUG] Expanding action 7 with prob 0.0936
# [DEBUG] Expanding action 8 with prob 0.0680
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.17
# [DEBUG] Backpropagation - Node visit_count: 3, total_value: 0.48
# [DEBUG] Backpropagation - Node visit_count: 18, total_value: 1.80
# [DEBUG] Backpropagation - Node visit_count: 89, total_value: 2.76
# [RESULT] Chosen action: 5
#
# [SIMULATION 90]
# Policy probs from model: [0.03950744 0.05526657 0.04558529 0.31794927 0.02352849 0.06859742
#  0.0508101  0.23248512 0.16627033]
# Action probs after filtering: {0: 0.03950744, 4: 0.023528492, 5: 0.06859742, 6: 0.0508101, 7: 0.23248512, 8: 0.16627033}
# [DEBUG] Evaluated value: 0.50
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0395
# [DEBUG] Expanding action 4 with prob 0.0235
# [DEBUG] Expanding action 5 with prob 0.0686
# [DEBUG] Expanding action 6 with prob 0.0508
# [DEBUG] Expanding action 7 with prob 0.2325
# [DEBUG] Expanding action 8 with prob 0.1663
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.50
# [DEBUG] Backpropagation - Node visit_count: 3, total_value: -1.05
# [DEBUG] Backpropagation - Node visit_count: 19, total_value: 2.31
# [DEBUG] Backpropagation - Node visit_count: 90, total_value: 2.26
# [RESULT] Chosen action: 2
#
# [SIMULATION 91]
# Policy probs from model: [0.08135501 0.11341363 0.03672523 0.11902027 0.11302637 0.07630931
#  0.26889506 0.08293834 0.10831687]
# Action probs after filtering: {0: 0.08135501, 3: 0.11902027, 5: 0.07630931, 6: 0.26889506, 7: 0.082938336, 8: 0.10831687}
# [DEBUG] Evaluated value: -0.02
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0814
# [DEBUG] Expanding action 3 with prob 0.1190
# [DEBUG] Expanding action 5 with prob 0.0763
# [DEBUG] Expanding action 6 with prob 0.2689
# [DEBUG] Expanding action 7 with prob 0.0829
# [DEBUG] Expanding action 8 with prob 0.1083
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.02
# [DEBUG] Backpropagation - Node visit_count: 4, total_value: 0.50
# [DEBUG] Backpropagation - Node visit_count: 20, total_value: 2.28
# [DEBUG] Backpropagation - Node visit_count: 91, total_value: 2.28
# [RESULT] Chosen action: 8
#
# [SIMULATION 92]
# Policy probs from model: [0.04538523 0.00750888 0.02216219 0.4364166  0.00999547 0.03726502
#  0.02058815 0.15354845 0.26712993]
# Action probs after filtering: {0: 0.04538523, 3: 0.4364166, 4: 0.009995474, 5: 0.03726502, 7: 0.15354845, 8: 0.26712993}
# [DEBUG] Evaluated value: 0.50
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0454
# [DEBUG] Expanding action 3 with prob 0.4364
# [DEBUG] Expanding action 4 with prob 0.0100
# [DEBUG] Expanding action 5 with prob 0.0373
# [DEBUG] Expanding action 7 with prob 0.1535
# [DEBUG] Expanding action 8 with prob 0.2671
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.50
# [DEBUG] Backpropagation - Node visit_count: 3, total_value: -0.70
# [DEBUG] Backpropagation - Node visit_count: 21, total_value: 2.79
# [DEBUG] Backpropagation - Node visit_count: 92, total_value: 1.78
# [RESULT] Chosen action: 7
#
# [SIMULATION 93]
# Policy probs from model: [0.06232195 0.03316196 0.0294079  0.5327428  0.02249231 0.04179076
#  0.03086508 0.09062338 0.15659392]
# Action probs after filtering: {3: 0.5327428, 4: 0.022492306, 5: 0.041790765, 6: 0.030865075, 7: 0.09062338, 8: 0.15659392}
# [DEBUG] Evaluated value: 0.54
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 3 with prob 0.5327
# [DEBUG] Expanding action 4 with prob 0.0225
# [DEBUG] Expanding action 5 with prob 0.0418
# [DEBUG] Expanding action 6 with prob 0.0309
# [DEBUG] Expanding action 7 with prob 0.0906
# [DEBUG] Expanding action 8 with prob 0.1566
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.54
# [DEBUG] Backpropagation - Node visit_count: 2, total_value: -0.72
# [DEBUG] Backpropagation - Node visit_count: 22, total_value: 3.33
# [DEBUG] Backpropagation - Node visit_count: 93, total_value: 1.23
# [RESULT] Chosen action: 0
#
# [SIMULATION 94]
# Policy probs from model: [0.09100981 0.01680712 0.02721534 0.53668827 0.00675114 0.00967886
#  0.01475693 0.11289052 0.18420199]
# Action probs after filtering: {0: 0.09100981, 3: 0.53668827, 4: 0.006751142, 5: 0.009678859, 6: 0.014756929, 7: 0.11289052}
# [DEBUG] Evaluated value: 0.91
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0910
# [DEBUG] Expanding action 3 with prob 0.5367
# [DEBUG] Expanding action 4 with prob 0.0068
# [DEBUG] Expanding action 5 with prob 0.0097
# [DEBUG] Expanding action 6 with prob 0.0148
# [DEBUG] Expanding action 7 with prob 0.1129
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.91
# [DEBUG] Backpropagation - Node visit_count: 3, total_value: -1.26
# [DEBUG] Backpropagation - Node visit_count: 23, total_value: 4.23
# [DEBUG] Backpropagation - Node visit_count: 94, total_value: 0.33
# [RESULT] Chosen action: 7
#
# [SIMULATION 95]
# Policy probs from model: [0.15867257 0.04549348 0.0359264  0.16449393 0.0896571  0.04320948
#  0.19528645 0.1198388  0.14742169]
# Action probs after filtering: {0: 0.15867257, 3: 0.16449393, 4: 0.0896571, 6: 0.19528645, 7: 0.119838804, 8: 0.14742169}
# [DEBUG] Evaluated value: -0.23
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.1587
# [DEBUG] Expanding action 3 with prob 0.1645
# [DEBUG] Expanding action 4 with prob 0.0897
# [DEBUG] Expanding action 6 with prob 0.1953
# [DEBUG] Expanding action 7 with prob 0.1198
# [DEBUG] Expanding action 8 with prob 0.1474
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.23
# [DEBUG] Backpropagation - Node visit_count: 5, total_value: 0.73
# [DEBUG] Backpropagation - Node visit_count: 24, total_value: 4.00
# [DEBUG] Backpropagation - Node visit_count: 95, total_value: 0.56
# [RESULT] Chosen action: 3
#
# [SIMULATION 96]
# Policy probs from model: [0.08249306 0.17261122 0.03521618 0.1307665  0.12610903 0.0353613
#  0.21096162 0.13103615 0.07544493]
# Action probs after filtering: {0: 0.08249306, 3: 0.1307665, 4: 0.12610903, 5: 0.0353613, 7: 0.13103615, 8: 0.07544493}
# [DEBUG] Evaluated value: 0.01
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0825
# [DEBUG] Expanding action 3 with prob 0.1308
# [DEBUG] Expanding action 4 with prob 0.1261
# [DEBUG] Expanding action 5 with prob 0.0354
# [DEBUG] Expanding action 7 with prob 0.1310
# [DEBUG] Expanding action 8 with prob 0.0754
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.01
# [DEBUG] Backpropagation - Node visit_count: 6, total_value: 0.72
# [DEBUG] Backpropagation - Node visit_count: 25, total_value: 4.01
# [DEBUG] Backpropagation - Node visit_count: 96, total_value: 0.55
# [RESULT] Chosen action: 1
#
# [SIMULATION 97]
# Policy probs from model: [0.02943154 0.04154712 0.07148345 0.3357332  0.02243397 0.08905201
#  0.06230467 0.15847576 0.18953827]
# Action probs after filtering: {0: 0.02943154, 3: 0.3357332, 4: 0.022433972, 6: 0.06230467, 7: 0.15847576, 8: 0.18953827}
# [DEBUG] Evaluated value: 0.36
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0294
# [DEBUG] Expanding action 3 with prob 0.3357
# [DEBUG] Expanding action 4 with prob 0.0224
# [DEBUG] Expanding action 6 with prob 0.0623
# [DEBUG] Expanding action 7 with prob 0.1585
# [DEBUG] Expanding action 8 with prob 0.1895
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.36
# [DEBUG] Backpropagation - Node visit_count: 3, total_value: -0.39
# [DEBUG] Backpropagation - Node visit_count: 26, total_value: 4.37
# [DEBUG] Backpropagation - Node visit_count: 97, total_value: 0.19
# [RESULT] Chosen action: 8
#
# [SIMULATION 98]
# Policy probs from model: [0.08782494 0.07333929 0.15010214 0.13822152 0.06789906 0.06305994
#  0.2937037  0.08195506 0.0438943 ]
# Action probs after filtering: {0: 0.08782494, 2: 0.15010214, 4: 0.067899056, 5: 0.06305994, 6: 0.2937037, 8: 0.0438943}
# [DEBUG] Evaluated value: -0.11
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0878
# [DEBUG] Expanding action 2 with prob 0.1501
# [DEBUG] Expanding action 4 with prob 0.0679
# [DEBUG] Expanding action 5 with prob 0.0631
# [DEBUG] Expanding action 6 with prob 0.2937
# [DEBUG] Expanding action 8 with prob 0.0439
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: -0.11
# [DEBUG] Backpropagation - Node visit_count: 4, total_value: -0.48
# [DEBUG] Backpropagation - Node visit_count: 27, total_value: 4.26
# [DEBUG] Backpropagation - Node visit_count: 98, total_value: 0.30
# [RESULT] Chosen action: 2
#
# [SIMULATION 99]
# Policy probs from model: [0.05818198 0.13636115 0.0750158  0.11757013 0.10304852 0.11365649
#  0.24213561 0.0569508  0.0970795 ]
# Action probs after filtering: {0: 0.058181975, 2: 0.0750158, 3: 0.11757013, 5: 0.11365649, 6: 0.24213561, 8: 0.0970795}
# [DEBUG] Evaluated value: 0.16
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0582
# [DEBUG] Expanding action 2 with prob 0.0750
# [DEBUG] Expanding action 3 with prob 0.1176
# [DEBUG] Expanding action 5 with prob 0.1137
# [DEBUG] Expanding action 6 with prob 0.2421
# [DEBUG] Expanding action 8 with prob 0.0971
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.16
# [DEBUG] Backpropagation - Node visit_count: 5, total_value: -0.64
# [DEBUG] Backpropagation - Node visit_count: 28, total_value: 4.42
# [DEBUG] Backpropagation - Node visit_count: 99, total_value: 0.14
# [RESULT] Chosen action: 6
#
# [SIMULATION 100]
# Policy probs from model: [0.04626515 0.09793344 0.03291934 0.22804348 0.0934746  0.06909436
#  0.10443866 0.17523584 0.15259506]
# Action probs after filtering: {0: 0.046265148, 2: 0.03291934, 5: 0.06909436, 6: 0.10443866, 7: 0.17523584, 8: 0.15259506}
# [DEBUG] Evaluated value: 0.52
# [DEBUG] expand() called with policy_probs type: <class 'dict'>
# [DEBUG] Expanding action 0 with prob 0.0463
# [DEBUG] Expanding action 2 with prob 0.0329
# [DEBUG] Expanding action 5 with prob 0.0691
# [DEBUG] Expanding action 6 with prob 0.1044
# [DEBUG] Expanding action 7 with prob 0.1752
# [DEBUG] Expanding action 8 with prob 0.1526
# [DEBUG] Backpropagation - Node visit_count: 1, total_value: 0.52
# [DEBUG] Backpropagation - Node visit_count: 4, total_value: -1.57
# [DEBUG] Backpropagation - Node visit_count: 29, total_value: 4.94
# [DEBUG] Backpropagation - Node visit_count: 100, total_value: -0.38
# [RESULT] Chosen action: 0
# MCTS 실행 완료!
