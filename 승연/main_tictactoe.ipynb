# %% [markdown]
# # Train Cycle

# %% [markdown]
# ## import

# %%
import torch
import torch.optim as optim
import os
import math

# %%
print(f"MPS 장치를 지원하도록 build가 되었는가? {torch.backends.mps.is_built()}")
print(f"MPS 장치가 사용 가능한가? {torch.backends.mps.is_available()}")
# Out:
# MPS 장치를 지원하도록 build가 되었는가? True
# MPS 장치가 사용 가능한가? True

# %%
os.chdir('/Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연')
from config import *

from enemy_agents import *
from environment import *
from evaluate import *
from file_save_load import *
from mcts import *
from net import *
from train_network import *
from visualizing import *

# %%
print(config)
# Out:
# # Environment
# STATE_SIZE = (3, 3)
# WIN_CONDITION = 3
# F_PATH = /Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_files
# F_NAME = 250218-3
#
# ALLOW_TRANSPOSE = True
# DATA_AGUMENTATION = True
#
# # state
# NUM_HISTORY = 0
# PLAYER_INFO = True
#
# # enemy agents
# AB_DEPTH = 100
# MCS_PO_NUM =100
# MCTS_EV_NUM = 100
#
# # net
# ACTION_SIZE = 9
# STATE_DIM = 3
#
# CONV_UNITS = 64
# RESIDUAL_NUM = 8
#
# DEVICE = mps
#
# # mcts
# C_PUCT = 5
# EVAL_CNT = 200
# TEMPERATURE = 1.0
# TEMPERATURE_DECAY = 0.9
#
# # train
# LEARN_RATE = 0.001
# GAMMA = 0.1
# TOTAL_SP_NUM = 100
# SP_NUM_TRAIN = 1
# EXPLORE_REGULATION = 4
#
# CROSS_ENTROPY = CrossEntropyLoss()
#
# BATCHSIZE = 256
# TRAIN_EPOCHS = 10
# MEM_SIZE = 30000
#
# EPISODES = 100
#
# # evaluation
# EVAL_NUM_GAME = 20
# TEST_NUM_GAME = 10
# CRITERIA = 0.5
#
# EVAL_FREQUENCY = 10

# %% [markdown]
# ## parameter

# %%
os.chdir('/Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_files')

# %%
model_type = ResNet()
env = Environment(STATE_SIZE, WIN_CONDITION)
eval = Evaluate(F_NAME, model_type)
Train = TrainNetwork(F_NAME, model_type)
# Out:
#     Create '250218-3_model_latest.pkl'
#     Create '250218-3_history.pkl'

# %%
Train.train_cycle(eval)
# Out:
# - - - - Episode 1/50 - - - -
#     Create '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 20초 입니다.
# /Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_network.py:174: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   X = torch.tensor(states, dtype=torch.float32).to(self.device) # (batch_size, STATE_DIM, env.n, env.n)
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 1초 입니다.
#
#  << policy loss: 0.10946 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 2/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 24초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.09095 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Create '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.525 / win:5 / draw:11 / lose:4
# << Game image succefully saved in 'game_images/250225_1_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_1_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 15초 입니다.
#
# - - - - Episode 3/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 23초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.06458 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 4/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.05621 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Create '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.6 / win:8 / draw:8 / lose:4
# << Game image succefully saved in 'game_images/250225_3_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_3_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 4분 56초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 0.95 / win:9 / draw:1 / lose:0
# << Game image succefully saved in 'game_images/250225_3_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_3_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.5 / win:0 / draw:10 / lose:0
# << Game image succefully saved in 'game_images/250225_3_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_3_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.35 / win:0 / draw:7 / lose:3
# << Game image succefully saved in 'game_images/250225_3_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_3_mcts_white.png'. >>
# - - - - Episode 5/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.05156 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 6/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04791 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.575 / win:6 / draw:11 / lose:3
# << Game image succefully saved in 'game_images/250225_5_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_5_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 5분 2초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 0.85 / win:8 / draw:1 / lose:1
# << Game image succefully saved in 'game_images/250225_5_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_5_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.5 / win:3 / draw:4 / lose:3
# << Game image succefully saved in 'game_images/250225_5_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_5_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.5 / win:0 / draw:10 / lose:0
# << Game image succefully saved in 'game_images/250225_5_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_5_mcts_white.png'. >>
# - - - - Episode 7/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 6 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 25초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.0484 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 8/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 29초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04737 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.575 / win:7 / draw:9 / lose:4
# << Game image succefully saved in 'game_images/250225_7_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_7_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 5분 8초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 0.9 / win:8 / draw:2 / lose:0
# << Game image succefully saved in 'game_images/250225_7_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_7_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.6 / win:4 / draw:4 / lose:2
# << Game image succefully saved in 'game_images/250225_7_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_7_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.55 / win:2 / draw:7 / lose:1
# << Game image succefully saved in 'game_images/250225_7_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_7_mcts_white.png'. >>
# - - - - Episode 9/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04411 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 10/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 30초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04339 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:5 / draw:9 / lose:6
# << Game image succefully saved in 'game_images/250225_9_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_9_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 16초 입니다.
#
# - - - - Episode 11/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 33초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04556 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 12/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04705 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.375 / win:3 / draw:9 / lose:8
# << Game image succefully saved in 'game_images/250225_11_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_11_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 18초 입니다.
#
# - - - - Episode 13/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 32초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04932 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 14/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04746 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.5 / win:4 / draw:12 / lose:4
# << Game image succefully saved in 'game_images/250225_13_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_13_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 11초 입니다.
#
# - - - - Episode 15/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 30초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04019 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 16/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 8 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04323 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:6 / draw:7 / lose:7
# << Game image succefully saved in 'game_images/250225_15_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_15_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 5초 입니다.
#
# - - - - Episode 17/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04809 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 18/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 35초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04569 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.55 / win:4 / draw:14 / lose:2
# << Game image succefully saved in 'game_images/250225_17_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_17_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 17초 입니다.
#
# - - - - Episode 19/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 8 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 31초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.0459 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 20/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04804 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.575 / win:8 / draw:7 / lose:5
# << Game image succefully saved in 'game_images/250225_19_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_19_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 5분 8초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 1.0 / win:10 / draw:0 / lose:0
# << Game image succefully saved in 'game_images/250225_19_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_19_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.55 / win:3 / draw:5 / lose:2
# << Game image succefully saved in 'game_images/250225_19_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_19_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.35 / win:0 / draw:7 / lose:3
# << Game image succefully saved in 'game_images/250225_19_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_19_mcts_white.png'. >>
# - - - - Episode 21/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04824 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# TEMPERATURE_DECAY = 0.0
# - - - - Episode 22/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04631 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.55 / win:7 / draw:8 / lose:5
# << Game image succefully saved in 'game_images/250225_21_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_21_best_white.png'. >>
#     # eval 소요 시간:  0시간 4분 51초 입니다.
#
# - - - - Episode 23/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 31초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04413 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 24/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 6 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04447 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.575 / win:7 / draw:9 / lose:4
# << Game image succefully saved in 'game_images/250225_23_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_23_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 4분 59초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 0.85 / win:7 / draw:3 / lose:0
# << Game image succefully saved in 'game_images/250225_23_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_23_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.55 / win:2 / draw:7 / lose:1
# << Game image succefully saved in 'game_images/250225_23_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_23_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.4 / win:0 / draw:8 / lose:2
# << Game image succefully saved in 'game_images/250225_23_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_23_mcts_white.png'. >>
# - - - - Episode 25/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 30초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04498 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 26/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04622 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.525 / win:6 / draw:9 / lose:5
# << Game image succefully saved in 'game_images/250225_25_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_25_best_white.png'. >>
#     # eval 소요 시간:  0시간 4분 53초 입니다.
#
# - - - - Episode 27/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 30초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.0459 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 28/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04209 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:3 / draw:13 / lose:4
# << Game image succefully saved in 'game_images/250225_27_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_27_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 26초 입니다.
#
# - - - - Episode 29/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04443 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 30/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 31초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04702 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:6 / draw:7 / lose:7
# << Game image succefully saved in 'game_images/250225_29_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_29_best_white.png'. >>
#     # eval 소요 시간:  0시간 4분 56초 입니다.
#
# - - - - Episode 31/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04903 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 32/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04804 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:5 / draw:9 / lose:6
# << Game image succefully saved in 'game_images/250225_31_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_31_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 7초 입니다.
#
# - - - - Episode 33/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04475 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 34/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04481 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:1 / draw:17 / lose:2
# << Game image succefully saved in 'game_images/250225_33_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_33_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 10초 입니다.
#
# - - - - Episode 35/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 8 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04517 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 36/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04188 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.5 / win:5 / draw:10 / lose:5
# << Game image succefully saved in 'game_images/250225_35_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_35_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 12초 입니다.
#
# - - - - Episode 37/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04326 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 38/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04188 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.45 / win:6 / draw:6 / lose:8
# << Game image succefully saved in 'game_images/250225_37_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_37_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 18초 입니다.
#
# - - - - Episode 39/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 6 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04057 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 40/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04515 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.575 / win:5 / draw:13 / lose:2
# << Game image succefully saved in 'game_images/250225_39_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_39_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 5분 29초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 1.0 / win:10 / draw:0 / lose:0
# << Game image succefully saved in 'game_images/250225_39_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_39_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.7 / win:4 / draw:6 / lose:0
# << Game image succefully saved in 'game_images/250225_39_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_39_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.5 / win:0 / draw:10 / lose:0
# << Game image succefully saved in 'game_images/250225_39_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_39_mcts_white.png'. >>
# - - - - Episode 41/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 26초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04317 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 42/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04072 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.475 / win:6 / draw:7 / lose:7
# << Game image succefully saved in 'game_images/250225_41_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_41_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 0초 입니다.
#
# - - - - Episode 43/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 28초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04061 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 44/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 7 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 48초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04073 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.55 / win:7 / draw:8 / lose:5
# << Game image succefully saved in 'game_images/250225_43_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_43_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 28초 입니다.
#
# - - - - Episode 45/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04138 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 46/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 31초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04192 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.5 / win:4 / draw:12 / lose:4
# << Game image succefully saved in 'game_images/250225_45_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_45_best_white.png'. >>
#     # eval 소요 시간:  0시간 5분 34초 입니다.
#
# - - - - Episode 47/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 33초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04303 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 48/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 6 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 27초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04252 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Load model from '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12
# Evaluate Evaluate network: 20/16
# Evaluate Evaluate network: 20/20
# Evaluate network: 0.6 / win:8 / draw:8 / lose:4
# << Game image succefully saved in 'game_images/250225_47_best_black.png'. >>
# << Game image succefully saved in 'game_images/250225_47_best_white.png'. >>
#     Save model parameters in '250225_model_best.pkl'
#     # eval 소요 시간:  0시간 5분 38초 입니다.
#
#     Load model from '250225_model_best.pkl'
# Evaluate [1/3] vs. random: 10/2
# Evaluate [1/3] vs. random: 10/4
# Evaluate [1/3] vs. random: 10/6
# Evaluate [1/3] vs. random: 10/8
# Evaluate [1/3] vs. random: 10/10
# [1/3] vs. random: 0.95 / win:9 / draw:1 / lose:0
# << Game image succefully saved in 'game_images/250225_47_random_black.png'. >>
# << Game image succefully saved in 'game_images/250225_47_random_white.png'. >>
# Evaluate [2/3] vs. mcs: 10/2
# Evaluate [2/3] vs. mcs: 10/4
# Evaluate [2/3] vs. mcs: 10/6
# Evaluate [2/3] vs. mcs: 10/8
# Evaluate [2/3] vs. mcs: 10/10
# [2/3] vs. mcs: 0.5 / win:2 / draw:6 / lose:2
# << Game image succefully saved in 'game_images/250225_47_mcs_black.png'. >>
# << Game image succefully saved in 'game_images/250225_47_mcs_white.png'. >>
# Evaluate [3/3] vs. mcts: 10/2
# Evaluate [3/3] vs. mcts: 10/4
# Evaluate [3/3] vs. mcts: 10/6
# Evaluate [3/3] vs. mcts: 10/8
# Evaluate [3/3] vs. mcts: 10/10
# [3/3] vs. mcts: 0.5 / win:0 / draw:10 / lose:0
# << Game image succefully saved in 'game_images/250225_47_mcts_black.png'. >>
# << Game image succefully saved in 'game_images/250225_47_mcts_white.png'. >>
# - - - - Episode 49/50 - - - -
#     Create '250225_model_latest.pkl'
#  << n_steps: 5 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 24초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04087 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
# - - - - Episode 50/50 - - - -
#     Load model from '250225_model_latest.pkl'
#  << n_steps: 9 >>
#     Save '250225_history.pkl'
#     # self play 소요 시간:  0시간 0분 33초 입니다.
#
#     Save model parameters in '250225_model_latest.pkl'
#     # train 소요 시간:  0시간 0분 0초 입니다.
#
#  << policy loss: 0.04087 / value_loss: 0.0 >>
#     Save '250225_loss_data.pkl'
#     Save '250225_step.pkl'
#     Load model from '250225_model_latest.pkl'
#     Create '250225_model_best.pkl'
#  << Start Evaluation w/ best >>
# Evaluate Evaluate network: 20/4
# Evaluate Evaluate network: 20/8
# Evaluate Evaluate network: 20/12

# %%
df = pd.DataFrame(eval.result_list)
df.columns = ("label", "average_point", "win_num", "draw_num", "lose_num")
df.to_csv("/Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_files/250218-2_result_data.csv")

# %%
len(Train.step_list)
# Out:
# 500

# %%
df = pd.DataFrame(np.stack([Train.policy_loss_list, Train.value_loss_list, Train.loss_list], axis=1))
df.columns = ("p_loss", "v_loss", "total_loss")
df.to_csv("/Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_files/250218-2_train_data.csv")

# %%
df = pd.DataFrame(np.array(Train.step_list).reshape(-1,1))
# df.columns = ("sp_num_step")
df.to_csv("/Users/seungyeonlee/Documents/GitHub/24-2-TicTacToe/승연/train_files/250218-2_step_data.csv")

# %%
env = Environment(STATE_SIZE, WIN_CONDITION)
model = load_model("250225_model_best.pkl", model_type)
agent = Mcts(model, 0.0)

is_done = False
n_steps = 0
state = State()

while not is_done:
    n_steps += 1
    env.render(state)
    print("-"*10)

    if n_steps % 2 == 0:
        action = agent.get_action(state)
    else:
        action = int(input("choose action (0~8):"))

    state, is_done, is_lose = env.step(state, action)

reward = env.get_first_reward(state)
print(f"reward of first player: {reward}")
# Out:
#     Create '250225_model_best.pkl'
# . . .
# . . .
# . . .
# ----------
# . . .
# . ○ .
# . . .
# ----------
# . . .
# . ○ .
# ● . .
# ----------
# . . .
# . ○ .
# ● . ○
# ----------
# . . .
# . ○ ●
# ● . ○
# ----------
# reward of first player: 1
